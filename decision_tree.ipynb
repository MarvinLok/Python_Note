# %% [markdown]
# <a href="https://colab.research.google.com/github/MarvinLok/Python_Note/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import datasets
from sklearn import tree
import pandas as pd
import pydotplus
import matplotlib.pyplot as plt

# %%
iris=datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# 分割特征和标签
X = df.drop('species', axis=1)  # 特征（4列）
y = df['species']

X_array = iris.data[:, [0, 2]]
y_array=iris.target

# %%
clf = DecisionTreeClassifier(criterion='gini', random_state=42)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
clf.score(X,y)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,8),dpi=150)
tree_diagram = tree.plot_tree(clf, feature_names = X.columns, class_names = clf.classes_, filled=True)
